# %%
import pandas as pd

# %%
df=pd.read_csv(f"C:\Users\Sayed Al Rafi\Documents\Data Desktop\Data_Analysis\ML project\CI-CD_Project\Penguin-Species-Prediction\data\penguins.csv")
# Out:
#   Cell In[3], line 1
#     df=pd.read_csv(f"C:\Users\Sayed Al Rafi\Documents\Data Desktop\Data_Analysis\ML project\CI-CD_Project\Penguin-Species-Prediction\data\penguins.csv")
#                                                                                                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
